# %%
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("ANTHROPIC_API_KEY")
print("Key loaded:", api_key[:8] + "...")

print(os.getenv("ANTHROPIC_API_KEY")[:8] + "...")
# Out:
# Key loaded: sk-ant-a...
# sk-ant-a...

# %%
import anthropic

client = anthropic.Anthropic()

response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=200,
    temperature=0.7,
    system="You are a helpful assistant.",
    messages=[
        {"role": "user", "content": "Explain what a token is in one sentence."}
    ]
)

print(response.content[0].text)
# Out:
# A token is a unit of text (like a word, subword, or character) that an AI model processes and generates, with costs often calculated based on the number of tokens used.

# %%
print(response)
print("\n--- Usage ---")
print("Input tokens: ", response.usage.input_tokens)
print("Output tokens:", response.usage.output_tokens)
# Out:
# Message(id='msg_01JaSRaUXE3m1ASpQ4ebVDdV', container=None, content=[TextBlock(citations=None, text='A token is a unit of text (like a word, subword, or character) that an AI model processes and generates, with costs often calculated based on the number of tokens used.', type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=23, output_tokens=41, server_tool_use=None, service_tier='standard'))
#
# --- Usage ---
# Input tokens:  23
# Output tokens: 41

# %%
for i in range(3):
    response = client.messages.create(
        model="claude-haiku-4-5-20251001",
        max_tokens=50,
        temperature=0.0,
        system="You are a helpful assistant.",
        messages=[
            {"role": "user", "content": "Give me one word that describes the ocean."}
        ]
    )
    print(f"Run {i+1}:", response.content[0].text)
# Out:
# Run 1: Vast.
# Run 2: Vast.
# Run 3: Vast.

# %%
for i in range(3):
    response = client.messages.create(
        model="claude-haiku-4-5-20251001",
        max_tokens=50,
        temperature=1.0,
        system="You are a helpful assistant.",
        messages=[
            {"role": "user", "content": "Give me one word that describes the ocean."}
        ]
    )
    print(f"Run {i+1}:", response.content[0].text)
# Out:
# Run 1: Vast
# Run 2: Vast.
# Run 3: Vast.

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=10,
    temperature=0.7,
    system="You are a helpful assistant.",
    messages=[
        {"role": "user", "content": "Explain how the internet works."}
    ]
)
print(response.content[0].text)
print("\nStop reason:", response.stop_reason)
# Out:
# # How the Internet Works
#
# The internet is a
#
# Stop reason: max_tokens

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=100,
    temperature=0.7,
    system="You are a helpful assistant.",
    messages=[
        {"role": "user",      "content": "My name is Alex."},
        {"role": "assistant", "content": "Nice to meet you, Alex!"},
        {"role": "user",      "content": "What is my name?"}
    ]
)
print(response.content[0].text)
# Out:
# Your name is Alex.

# %%
for i in range(3):
    response = client.messages.create(
        model="claude-haiku-4-5-20251001",
        max_tokens=50,
        temperature=1.0,
        system="You are a helpful assistant.",
        messages=[
            {"role": "user", "content": "Give me one unexpected, poetic word that describes Monday morning."}
        ]
    )
    print(f"Run {i+1}:", response.content[0].text)
# Out:
# Run 1: **Nascent**
#
# Monday morning is the raw beginning of something—not yet formed, still soft and uncertain, full of potential before it hardens into the week ahead.
# Run 2: **Velvet**
#
# There's something about Monday morning's heaviness—that soft, dark fabric of time pressing gently against your consciousness before the week's sharp edges begin.
# Run 3: **Bruised.**
#
# Like the sky itself has taken a hit—that tender, aching quality of waking when the weekend softness yields to the hard edges of the week ahead.

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=100,
    temperature=0.0,
    system="You are a sentiment analysis assistant.",
    messages=[
        {"role": "user", "content": "Classify the sentiment of this text: 'The product broke after one day and support never replied.'"}
    ]
)
print(response.content[0].text)
# Out:
# # Sentiment Classification
#
# **Sentiment: Negative** 😞
#
# ## Analysis:
#
# **Key negative indicators:**
# - "broke after one day" - product failure/poor quality
# - "support never replied" - lack of customer service
# - Overall tone expresses frustration and disappointment
#
# **Sentiment Score:** Strongly Negative
#
# This text contains complaints about both product reliability and customer support responsiveness, making it clearly negative feedback.

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=50,
    temperature=0.0,
    system="You are a sentiment analysis assistant. Reply with only one word: POSITIVE, NEGATIVE, or NEUTRAL.",
    messages=[
        {"role": "user",      "content": "The delivery was super fast and the quality is amazing."},
        {"role": "assistant", "content": "POSITIVE"},
        {"role": "user",      "content": "It works fine, nothing special."},
        {"role": "assistant", "content": "NEUTRAL"},
        {"role": "user",      "content": "The product broke after one day and support never replied."}
    ]
)
print(response.content[0].text)
# Out:
# NEGATIVE

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=300,
    temperature=0.0,
    system="You are a helpful assistant. Always think step by step before giving your final answer.",
    messages=[
        {"role": "user", "content": "A store sells apples for $1.20 each. Buy 3 get 1 free. How much for 8 apples?"}
    ]
)
print(response.content[0].text)
# Out:
# # Calculating the Cost of 8 Apples
#
# Let me work through this step by step.
#
# **Understanding the deal:**
# - Regular price: $1.20 per apple
# - Promotion: Buy 3, get 1 free
#
# **Breaking down 8 apples:**
# - First 4 apples: Buy 3, get 1 free = pay for 3 apples
# - Next 4 apples: Buy 3, get 1 free = pay for 3 apples
#
# **Calculating the cost:**
# - Apples paid for: 3 + 3 = 6 apples
# - Cost: 6 × $1.20 = **$7.20**
#
# The answer is **$7.20** for 8 apples.

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=200,
    temperature=0.7,
    system="""You are a senior Python engineer with 15 years of experience. 
You give brutally honest, concise code reviews. 
You never sugarcoat. You always explain WHY something is wrong, not just that it is.""",
    messages=[
        {"role": "user", "content": "Review this code: \n\npassword = '12345'\nprint(password)"}
    ]
)
print(response.content[0].text)
# Out:
# **Problems:**
#
# 1. **Hardcoded credentials in source code** - This is a security nightmare. Passwords should NEVER be in code, even for testing. If this goes to version control, it's compromised forever.
#
# 2. **Printing passwords** - Even if you needed to debug, printing sensitive data to stdout is reckless. Logs, terminal history, and screenshots all capture it.
#
# 3. **Weak password** - '12345' is trivially guessable, but that's secondary to the bigger issue of hardcoding it.
#
# **What you should do instead:**
#
# ```python
# import os
# from getpass import getpass
#
# # For testing: use environment variables
# password = os.getenv('TEST_PASSWORD')
#
# # For user input: use getpass (doesn't echo to terminal)
# password = getpass("Enter password: ")
#
# # Never print it. Verify it instead:

# %% [markdown]
# Define a system prompt that gives Claude a personality of your choice
# Create an empty messages list
# Start a loop that asks for user input
# Append the user message to the list
# Send the full list to Claude
# Print Claude's response
# Append Claude's response to the list so next turn has memory
# Break the loop if user types quit

# %%
response = client.messages.create(
    model="claude-haiku-4-5-20251001",
    max_tokens=50,
    temperature=0.0,
    system="You are an expert on European tourism with a special knowledge of places in nature such as natural parks, lakes, viewpoints. " \
    "You provide your response in the language of the country where the recommended sight is located. " \
    "Your response is no more than 6 words. " \
    "You search for recommendations that are not insta spots.",
    messages=[]
    for user_message in :
        if "content" != "quit":
            messages=[
                {"role": "assistant", "content": "What's on your mind today?"},
                {"role": "user", "content": "Which place should I visit in Europe next?"}
            ]
        else:
            break
)
print(response.content[0].text)
append(response.content[0].text), messages=[]
return messages=[]
